# %%
# The following code snippets are from
# https://www.youtube.com/watch?v=_uQrJ0TkZlc
# Python Tutorial - Python for Beginners
# 6 hours
# Mosh

# how to display

print('Hello, Class!')
print('o------')
print('*' * 10)

# variables of different types

price = 10
rating = 3.9
is_published = True
name = 'Class'

# getting inputs

birth_year = input('Birth year: ')
print(type(birth_year))
age = 2020 - int(birth_year)
print(type(age))
print(f"your age is: {age}")    # formatted string

# strings

course = 'Python Course for Beginners!'
course = "Python's Course for Beginners!"
course = 'Python for "Beginners"'
print(course[0])
# -1 is the index of the last character, unique to Python
print(course[-1])
print(course[-2])
print(course[0:3])
print(course[0:])
print(course[1:])  # print till the end
print(course[:5])  # print from the beginning
print(course[:])   # print all
clone = course[:]
print(clone)

# strings with multiple lines, use tripple quotes

course = '''
Hi, John,

Here's our first email to you.

Thanks,
'''
print(course)

# formatted string for dynamically generating tags or variables

first = 'John'
last = 'Smith'
# if we want to generate "John [Smith] is a coder" but hard to visualize
msg = f'{first} [{last}] is a coder'
print(msg)

# string methods, functions of a class/object

course = 'Python Course for Beginners!'
print(len(course))
print(course.upper())
print(course.lower())
print(course.find('P')) # returns the index of P, 0; if not found, return 0
print(course.replace('Beginners', 'Absolute Beginners'))
print(course.replace('P', 'J'))
print('Python' in course)  

# math functions

x = 2.9
print(round(x))
print(abs(-2.9))

# using the math module

import math

print(math.ceil(2.9))
print(math.floor(2.9))
# Out:
# Hello, Class!
# o------
# **********
# Birth year: 1992
# <class 'str'>
# <class 'int'>
# your age is: 28
# P
# "
# s
# Pyt
# Python for "Beginners"
# ython for "Beginners"
# Pytho
# Python for "Beginners"
# Python for "Beginners"
#
# Hi, John,
#
# Here's our first email to you.
#
# Thanks,
#
# John [Smith] is a coder
# 28
# PYTHON COURSE FOR BEGINNERS!
# python course for beginners!
# 0
# Python Course for Absolute Beginners!
# Jython Course for Beginners!
# True
# 3
# 2.9
# 3
# 2
